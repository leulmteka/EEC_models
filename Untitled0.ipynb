# %%
# !GIT_LFS_SKIP_SMUDGE=1 uv pip install -e ".[dev]" --prerelease disallow
# Out:
# Using Python 3.11.12 environment at: /usr
# Resolved 141 packages in 8.69s
#    Building deepspeed==0.15.4
#    Building deepspeed==0.15.4
#    Updating https://github.com/huggingface/lighteval.git (bb14995c4eccab5cabd450b1e5
#    Building deepspeed==0.15.4
#    Updating https://github.com/huggingface/lighteval.git (bb14995c4eccab5cabd450b1e5
#    Building deepspeed==0.15.4
#    Updating https://github.com/huggingface/lighteval.git (bb14995c4eccab5cabd450b1e5
#    Building rouge-score==0.1.2
#    Building deepspeed==0.15.4
#    Updating https://github.com/huggingface/lighteval.git (bb14995c4eccab5cabd450b1e5
#    Building rouge-score==0.1.2
#    Building open-r1 @ file:///content/drive/MyDrive/open-r1
#    Building deepspeed==0.15.4
#    Updating https://github.com/huggingface/lighteval.git (bb14995c4eccab5cabd450b1e5
#    Building rouge-score==0.1.2
#    Building open-r1 @ file:///content/drive/MyDrive/open-r1
# ⠙ Preparing packages... (0/47)
#    Building deepspeed==0.15.4
# ...

# %%
# !uv pip install -e ".[dev]" --prerelease allow
# Out:
# Using Python 3.11.12 environment at: /usr
# Resolved 141 packages in 966ms
#    Building open-r1 @ file:///content/drive/MyDrive/open-r1
#    Building open-r1 @ file:///content/drive/MyDrive/open-r1
#    Building open-r1 @ file:///content/drive/MyDrive/open-r1
#    Building open-r1 @ file:///content/drive/MyDrive/open-r1
#       Built open-r1 @ file:///content/drive/MyDrive/open-r1
# Prepared 1 package in 694ms
# Uninstalled 1 package in 0.61ms
# Installed 1 package in 0.98ms
#  ~ open-r1==0.1.0.dev0 (from file:///content/drive/MyDrive/open-r1)

# %%
# !MODEL=deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B
# !MODEL_ARGS="pretrained=$MODEL,dtype=bfloat16,max_model_length=32768,max_num_batched_tokens=32768,gpu_memory_utilization=0.8,generation_parameters={max_new_tokens:32768,temperature:0.6,top_p:0.95}"
# !OUTPUT_DIR=data/evals/$MODEL

# # AIME 2024
# !TASK=aime24
# !lighteval vllm $MODEL_ARGS "lighteval|aime24|0|0"   --use-chat-template --output-dir . aime24

# !lighteval vllm pretrained=deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B,dtype=half,max_model_length=32768,max_num_batched_tokens=32768,gpu_memory_utilization=0.8,generation_parameters="{max_new_tokens:32768,temperature:0.6,top_p:0.95}" aime24 --use-chat-template --output-dir data/evals/deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B
# !make evaluate MODEL=deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B TASK=aime24
# !make evaluate MODEL=deepseek-ai/DeepSeek-R1-Distill-Qwen-32B TASK=aime24 PARALLEL=data NUM_GPUS=8
# !python scripts/run_benchmarks.py --model-id {deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B}  --benchmarks aime24

# !lighteval vllm "pretrained=deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B,dtype=half,max_model_length=32768,max_num_batched_tokens=32768,gpu_memory_utilization=0.8,generation_parameters={max_new_tokens:32768,temperature:0.6,top_p:0.95}" "lighteval|aime25|0|0" --use-chat-template --output-dir data/evals/deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B;
# Out:
# [2025-04-11 00:41:00,810] [    INFO]: NumExpr defaulting to 2 threads. (utils.py:162)
# [2025-04-11 00:41:01,318] [    INFO]: PyTorch version 2.5.1 available. (config.py:54)
# [2025-04-11 00:41:01,320] [    INFO]: Polars version 1.21.0 available. (config.py:66)
# [2025-04-11 00:41:01,321] [    INFO]: Duckdb version 1.2.1 available. (config.py:77)
# [2025-04-11 00:41:01,322] [    INFO]: TensorFlow version 2.18.0 available. (config.py:112)
# [2025-04-11 00:41:01,324] [    INFO]: JAX version 0.5.2 available. (config.py:125)
# 2025-04-11 00:41:02.212355: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...
